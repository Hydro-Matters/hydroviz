# %%
import hydroviz

# %%
from hydroviz.io import OutputMGB
from hydroviz.maps import CatchmentsMap

# %%
out_file = "../data/MGB/mgb_out.nc"
mgb_poly_shp = "../data/MGB/Maroni_MGB_Catchments.shp"
mgb_riv_shp = "../data/MGB/Maroni_MGB_Drainage.shp"

mgb = OutputMGB(out_file, mgb_poly_shp, mgb_riv_shp)

# %%
cmap = CatchmentsMap(mgb, backend="folium")

# %%
m = cmap.get_catchments_map("discharge")

# %%
m
