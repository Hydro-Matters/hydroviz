# %%
import glob
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import hydroviz
import hydroviz.io as sdvio
import hydroviz.maps as sdvm
import hydroviz.plots as sdvpl

# %% [markdown]
# ## Set paths

# %%
inputdir = "../data/h2ivdi/input" # Path to directory containing input files and subdirectories
setsfile = "sets.json" # File containing sets definition
sword_shp_dir = "../data/SWORD/V16/shp/" # Path to directory containing sword shapefiles

# %%
res = sdvio.SwotObservationsSet(inputdir, setsfile, sword_shp_dir=sword_shp_dir, basinID=232, simplify_tolerance=0.001)

# %%
rmap = sdvm.ReachesMap(res, tiles="GoogleHybrid")
m = rmap.get_centerlines_map("width")
m
