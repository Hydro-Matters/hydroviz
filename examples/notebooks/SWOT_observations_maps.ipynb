# %%
import glob
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import swotdawgviz
import swotdawgviz.io as sdvio
import swotdawgviz.maps as sdvm
import swotdawgviz.plots as sdvpl

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Set paths

# %%
inputdir = "/mnt/data/input" # Path to directory containing input files and subdirectories
setsfile = "sets.json" # File containing sets definition
sword_shp_dir = "/mnt/data/SWORD/V16/shp/" # Path to directory containing sword shapefiles

# %%
res = sdvio.SwotObservationsSet(inputdir, setsfile, sword_shp_dir=sword_shp_dir, basinID=232, simplify_tolerance=0.001)

# %%
rmap = sdvm.ReachesMap(res, tiles="GoogleHybrid")
m = rmap.get_centerlines_map("width")
m
